# %%
import pandas as pd

# %%
df = pd.read_csv("new_file3.csv")
# Out:
# C:\Users\Kipplouser1\AppData\Local\Temp\ipykernel_3464\3677640229.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("new_file3.csv")

# %%
# Drop email which has NULL values
df2= df[df['Personal_Email'].notna()]

# %%
# Drp values which has no phone number
df2.dropna(subset=['phone_numbers'])
# Out:
#                     first_name      last_name
# anthony spina          anthony          spina  \
# david sainte             david         sainte
# eric bram                 eric           bram
# maria frallicciardi      maria  frallicciardi
# steven overturf         steven       overturf
# ...                        ...            ...
# don mcmillan               don       mcmillan
# dievina navarrete      dievina      navarrete
# al grabowski                al      grabowski
# jonathan gibbs        jonathan          gibbs
# bruce coombs             bruce         coombs
#
#                                                      linkedin_url
# anthony spina              linkedin.com/in/anthony-spina-823aab15  \
# david sainte                          linkedin.com/in/davidsainte
# eric bram                    linkedin.com/in/eric-c-bram-b2973518
# maria frallicciardi  linkedin.com/in/maria-frallicciardi-53b5645b
# steven overturf          linkedin.com/in/steven-overturf-14762192
# ...

# %%
df2
# Out:
#                     first_name      last_name
# anthony spina          anthony          spina  \
# david sainte             david         sainte
# eric bram                 eric           bram
# maria frallicciardi      maria  frallicciardi
# steven overturf         steven       overturf
# ...                        ...            ...
# don mcmillan               don       mcmillan
# dievina navarrete      dievina      navarrete
# al grabowski                al      grabowski
# jonathan gibbs        jonathan          gibbs
# bruce coombs             bruce         coombs
#
#                                                      linkedin_url
# anthony spina              linkedin.com/in/anthony-spina-823aab15  \
# david sainte                          linkedin.com/in/davidsainte
# eric bram                    linkedin.com/in/eric-c-bram-b2973518
# maria frallicciardi  linkedin.com/in/maria-frallicciardi-53b5645b
# steven overturf          linkedin.com/in/steven-overturf-14762192
# ...

# %%
df2.to_csv("emailandphone.csv")
