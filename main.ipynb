# %%
import pandas as pd

# %%
df = pd.read_csv("new_file3.csv")
# Out:
# C:\Users\Kipplouser1\AppData\Local\Temp\ipykernel_10980\3677640229.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("new_file3.csv")

# %%
# Extracting Values where personal value is NaN
df[df['Personal_Email'].isna()]
# Out:
#                  first_name  last_name
# charnie guttmann    charnie   guttmann  \
# colleen pinkham     colleen    pinkham
# vicki finley          vicki     finley
# michael brinton     michael    brinton
# marsha auguste       marsha    auguste
# ...                     ...        ...
# marcielle wray    marcielle       wray
# robert browning      robert   browning
# jenny boughner        jenny   boughner
# david chandler        david   chandler
# andrea goldstein     andrea  goldstein
#
#                                                  linkedin_url
# charnie guttmann    linkedin.com/in/charnie-guttmann-6301b313  \
# colleen pinkham      linkedin.com/in/colleen-pinkham-542b1941
# vicki finley             linkedin.com/in/vicki-finley-8706079
# michael brinton      linkedin.com/in/michael-brinton-14bb4525
# marsha auguste         linkedin.com/in/marsha-auguste-5057246
# ...                                                       ...
# ...

# %%
# Out:
#                  first_name  last_name
# charnie guttmann    charnie   guttmann  \
# colleen pinkham     colleen    pinkham
# vicki finley          vicki     finley
# michael brinton     michael    brinton
# marsha auguste       marsha    auguste
# ...                     ...        ...
# marcielle wray    marcielle       wray
# robert browning      robert   browning
# jenny boughner        jenny   boughner
# david chandler        david   chandler
# andrea goldstein     andrea  goldstein
#
#                                                  linkedin_url
# charnie guttmann    linkedin.com/in/charnie-guttmann-6301b313  \
# colleen pinkham      linkedin.com/in/colleen-pinkham-542b1941
# vicki finley             linkedin.com/in/vicki-finley-8706079
# michael brinton      linkedin.com/in/michael-brinton-14bb4525
# marsha auguste         linkedin.com/in/marsha-auguste-5057246
# ...                                                       ...
# ...
